# %% [markdown]
# # <center>Amazon Sales Dataset EDA <center>

# %% [markdown]
# <center><b> <h2 style="color:powderblue;"> About Author </h2></center></b>
#
# - Author : **Mohsin Shareef**
# - Project : **Amazon Sales Dataset**
#
# <center><b> <h2 style="color:powderblue;"> Contact Info </h2></center></b>
#
# - Email: mohsinshareef822@gmail.com
# - [Github](https://github.com/MohsinShareef)
# - [Linkdin](www.linkedin.com/in/mohsin-shareef-9231a1294)

# %% [markdown]
# <center> <b> <h2 style="color:powderblue;"> About Dataset </h2> </b> </center>
#
# - [Dataset Link:](https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset)
# <p>This dataset is having the data of 1K+ Amazon Product's Ratings and Reviews as per their details listed on the official website of Amazon </p>
#
# ### **Features**
#
# - product_id - Product ID
# - product_name - Name of the Product
# - category - Category of the Product
# - discounted_price - Discounted Price of the Product
# - actual_price - Actual Price of the Product
# - discount_percentage - Percentage of Discount for the Product
# - rating - Rating of the Product
# - rating_count - Number of people who voted for the Amazon rating
# - about_product - Description about the Product
# - user_id - ID of the user who wrote review for the Product
# - user_name - Name of the user who wrote review for the Product
# - review_id - ID of the user review
# - review_title - Short review
# - review_content - Long review
# - img_link - Image Link of the Product
# - product_link - Official Website Link of the Product
#
# ### **Inspiration**
#
# <p> Amazon is an American Tech Multi-National Company whose business interests include E-commerce, where they buy and store the inventory, and take care of everything from shipping and pricing to customer service and returns. I've created this dataset so that people can play with this dataset and do a lot of things as mentioned below </p>
#
# - Dataset Walkthrough
# - Understanding Dataset Hierarchy
# - Data Preprocessing
# - Exploratory Data Analysis
# - Data Visualization
# - Making Recommendation System
# <p> This is a list of some of that things that you can do on this dataset. It's not definitely limited to the one that is mentioned there but a lot more other things can also be done. </p>

# %% [markdown]
# <h2> <center> Task </center> </h2>
# <p> The process of Analyzing the Amazon Sales Dataset involves a methodical approach. First, we cleanse and prepare the data to ensure it is accurate and consistent. Following that, we summarize the data using descriptive metrics such as averages and ranges. The next step is to visualize the data through charts and graphs, which allows us to identify patterns and relationships. We also detect any outliers, which are atypical data points, and validate our assumptions about the dataset. Furthermore, we segment the data into meaningful groups to gain a more granular understanding. Finally, we synthesize our findings into a concise summary. </p>

# %% [markdown]
# <h3> <center> <b> Kernel Version Used </b></center> </h3>
# <ul>
#   <li> <b> Python 3.11.5 </b</li>
# </ul>
#
# <h3> <center> <b> Import Libraries </b></center> </h3>
# <ol>
# <ul>
# <li> List of following libraries</li>
# </ul>
#   <li>Pandas: Data manipulation and analysis</li>
#   <li>Numpy: Numerical operations and calculations</li>
#   <li>Matplotlib: Data visualization and plotting</li>
#   <li>Seaborn: Enhanced data visualization and statistical graphics</li>
#   <li>Scipy: Scientific computing and advanced mathematical operations</li>
# </ol>

# %%
# Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # <center> Load the Dataset and Explore  <center>
#
# ### <center> Load a CSV file then creating a dataframe </center>

# %%
# Load the dataset
# load the dataset from data folder amazon.csv file
df = pd.read_csv('./data/amazon.csv')

# %%
df.head(4)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
#
# ...

# %%
# Check the shape of this dataset
print(f"The number of rows are {df.shape[0]} and the number of columns are {df.shape[1]}")
# Out:
# The number of rows are 1465 and the number of columns are 16

# %%
# Basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
print(f"All columns name are: {df.columns}")
# Out:
# All columns name are: Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %% [markdown]
# ### <center> Observation Set 1 </center>
#
# - There are 16 columns and 1465 rows in the dataset.
# - The data type of all columns is object according to the python.
# - The columns in the datasets are:
#   - ['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link']
# - Easily convert the data type of these columns:
#   - 'discounted_price','actual_price', 'discount_percentage', 'rating', 'rating_count'

# %% [markdown]
# # <center> Explore the dataset columns by columns</center>

# %%
print(df['product_id'].nunique())
# Out:
# 1351

# %%
print(df['product_name'].nunique())
# Out:
# 1337

# %%
print(df['category'].nunique())
df['category'].value_counts()
# Out:
# 211
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                                                 49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                                    27
# ...

# %%
print(df['discounted_price'].unique())
# Out:
# ['₹399' '₹199' '₹329' '₹154' '₹149' '₹176.63' '₹229' '₹499' '₹299' '₹219'
#  '₹350' '₹159' '₹349' '₹13,999' '₹249' '₹13,490' '₹970' '₹279' '₹59'
#  '₹11,499' '₹14,999' '₹179' '₹389' '₹599' '₹99' '₹899' '₹32,999' '₹209'
#  '₹19,999' '₹999' '₹333' '₹507' '₹309' '₹1,199' '₹799' '₹6,999' '₹230'
#  '₹649' '₹15,999' '₹348' '₹32,990' '₹139' '₹263' '₹7,999' '₹1,599'
#  '₹26,999' '₹115' '₹10,901' '₹1,434' '₹7,299' '₹325' '₹29,999' '₹27,999'
#  '₹30,990' '₹269' '₹24,999' '₹18,990' '₹290' '₹345' '₹1,099' '₹719' '₹849'
#  '₹21,999' '₹449' '₹37,999' '₹7,390' '₹273.10' '₹15,990' '₹210' '₹1,299'
#  '₹347' '₹228' '₹1,499' '₹8,499' '₹20,990' '₹9,999' '₹489' '₹23,999'
#  '₹689' '₹1,699' '₹655' '₹749' '₹195' '₹416' '₹368' '₹29,990' '₹339'
#  '₹15,490' '₹9,490' '₹637' '₹1,089' '₹12,499' '₹1,399' '₹88' '₹57.89'
#  '₹205' '₹949' '₹379' '₹8,990' '₹486' '₹5,699' '₹709' '₹47,990' '₹320'
#  '₹129' '₹225' '₹547' '₹259' '₹239' '₹467' '₹11,990' '₹252' '₹204'
# ...

# %%
print(df['actual_price'].unique())
# Out:
# ['₹1,099' '₹349' '₹1,899' '₹699' '₹399' '₹1,000' '₹499' '₹299' '₹999'
#  '₹339' '₹799' '₹700' '₹899' '₹24,999' '₹21,990' '₹1,799' '₹22,900' '₹199'
#  '₹19,990' '₹19,999' '₹1,999' '₹750' '₹599' '₹666.66' '₹1,900' '₹45,999'
#  '₹695' '₹34,999' '₹1,599' '₹1,208' '₹475' '₹395' '₹2,199' '₹500' '₹2,100'
#  '₹12,999' '₹1,399' '₹21,999' '₹1,499' '₹47,900' '₹845' '₹1,400' '₹14,990'
#  '₹2,999' '₹42,999' '₹30,990' '₹3,999' '₹249' '₹19,125' '₹1,299' '₹39,999'
#  '₹40,990' '₹52,900' '₹800' '₹31,999' '₹1,809' '₹29,999' '₹65,000'
#  '₹20,000' '₹23,990' '₹15,999' '₹44,990' '₹44,999' '₹1,700' '₹595'
#  '₹27,990' '₹1,200' '₹34,990' '₹1,500' '₹49,990' '₹931' '₹2,399' '₹1,339'
#  '₹20,900' '₹15,990' '₹1,600' '₹849' '₹1,199' '₹22,990' '₹2,499' '₹47,990'
#  '₹485' '₹18,990' '₹11,000' '₹70,900' '₹549' '₹35,999' '₹1,699' '₹31,990'
#  '₹9,990' '₹16,990' '₹59,999' '₹600' '₹1,490' '₹2,299' '₹4,999' '₹1,749'
#  '₹1,100' '₹49,999' '₹56,790' '₹795' '₹798' '₹995' '₹1,39,900' '₹85,000'
# ...

# %%
print(df['discount_percentage'].unique())
# Out:
# ['64%' '43%' '90%' '53%' '61%' '85%' '65%' '23%' '50%' '33%' '55%' '63%'
#  '69%' '60%' '13%' '44%' '38%' '39%' '46%' '41%' '70%' '42%' '72%' '25%'
#  '51%' '73%' '0%' '80%' '28%' '67%' '58%' '35%' '45%' '62%' '54%' '27%'
#  '77%' '56%' '78%' '31%' '86%' '47%' '37%' '75%' '32%' '68%' '66%' '22%'
#  '57%' '17%' '52%' '88%' '20%' '59%' '40%' '26%' '29%' '83%' '71%' '15%'
#  '76%' '48%' '82%' '36%' '89%' '87%' '24%' '34%' '11%' '91%' '7%' '19%'
#  '79%' '21%' '81%' '18%' '49%' '30%' '84%' '10%' '6%' '14%' '74%' '4%'
#  '5%' '16%' '8%' '2%' '94%' '12%' '3%' '9%']

# %%
print(df['rating'].unique())
# Out:
# ['4.2' '4.0' '3.9' '4.1' '4.3' '4.4' '4.5' '3.7' '3.3' '3.6' '3.4' '3.8'
#  '3.5' '4.6' '3.2' '5.0' '4.7' '3.0' '2.8' '4' '3.1' '4.8' '2.3' '|' '2'
#  '3' '2.6' '2.9']

# %%
df[df['rating']=='|']
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...           ₹2,099
#
#      actual_price discount_percentage rating rating_count  \
# 1279       ₹2,499                 16%      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
print(df['rating_count'].unique())
# Out:
# ['24,269' '43,994' '7,928' ... '468' '8,031' '6,987']

# %%
print(df['about_product'].nunique())
# Out:
# 1293

# %%
print(df['user_id'].nunique())
# Out:
# 1194

# %%
print(df['user_name'].nunique())
# Out:
# 1194

# %%
print(df['review_id'].nunique())
# Out:
# 1194

# %%
print(df['review_title'].nunique())
# Out:
# 1194

# %%
print(df['review_content'].nunique())
# Out:
# 1212

# %%
print(df['img_link'].nunique())
# Out:
# 1412

# %%
print(df['product_link'].nunique())
# Out:
# 1465

# %% [markdown]
# ### <center> Observation Set 2 </center>
# - 1351 unique number of product_id.
# - 211 differnt categories in this dataset.
# - Indian Rupee (₹) use in this dataset.
# - 1 incorrect entry in rating column ('|').
# - product_id is 'B08L12N5H1'.
# - 1194 user_id use in this dataset.

# %% [markdown]
# # <center> Transforming Column Data Types from Object to Numeric </center>

# %%
# Convert the datatype of discounted_price column
df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
df['discounted_price'] = df['discounted_price'].str.replace(",",'')
df['discounted_price'] = df['discounted_price'].astype('float64')


# Convert the datatype of actual_pric column 
df['actual_price'] = df['actual_price'].str.replace("₹",'')
df['actual_price'] = df['actual_price'].str.replace(",",'')
df['actual_price'] = df['actual_price'].astype('float64')

# Convert the datatype of discount_percentage column
df['discount_percentage'] = df['discount_percentage'].str.replace("%",'')
df['discount_percentage'] = df['discount_percentage'].astype('float64')
df['discount_percentage'] = df['discount_percentage'] / 100

# %% [markdown]
# - product_id of rating columns is B08L12N5H1.
# - The rating is 3.9. So, I am going to give the item rating 3.9

# %%
# Convert the datatype of rating column
df['rating'] = df['rating'].str.replace("|",'3.9')
df['rating'] = df['rating'].astype('float64')

# Convert the datatype of rating_count column
df['rating_count'] = df['rating_count'].str.replace(",",'')
df['rating_count'] = df['rating_count'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
# Descriptive Statistics
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635             0.476915     4.096451
# std         6944.304394   10874.826864             0.216359     0.291620
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1650.000000             0.500000     4.100000
# 75%         1999.000000    4295.000000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %% [markdown]
# ### <center> Observation Set 3 </center>
# - In this dataset have object datatype in all columns.
# - 5 Object datatype columns convert into the float64 datatype.

# %% [markdown]
# # <center> Dealing with the Missing Values </center>

# %%
# Find the missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# rating_count           2
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# ### <center> Let's plot the missing values </center>

# %%
# make a figure size
plt.figure(figsize=(18, 8))
# plot the null values in each column
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# <center> <b>Figure-1:</b> Heatmap of Missing Values </center>

# %%
# Impute the missing values
df['rating_count'] = df['rating_count'].fillna(df['rating_count'].median())
df.isnull().sum().sort_values(ascending = False)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# # <center> Dead with Duplications Values</center>

# %%
# Fine the duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
duplicates = df.duplicated(subset=['product_id', 'product_name', 'category', 'discounted_price',
       'actual_price', 'discount_percentage', 'rating', 'rating_count',
       'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
       'review_content', 'img_link', 'product_link']).any()
print(duplicates)
# Out:
# False

# %% [markdown]
# # <center> Data Visualization </center>

# %%
# Plot actual_price vs. rating
plt.scatter(df['actual_price'], df['rating'])
plt.xlabel('Actual_price')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# <center> <b>Figure-2:</b> Scater plot of Actual Price and Rating column </center>

# %%
# Plot distribution of discounted_price
plt.figure(figsize=(18, 8))
plt.hist(df['discounted_price'])
plt.xlabel('Discounted Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <center> <b>Figure-3:</b> histogram plot of Discounted Price column </center>

# %%
# Plot distribution of actual_price
plt.figure(figsize=(18, 8))
plt.hist(df['actual_price'])
plt.xlabel('Actual Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <center> <b>Figure-4:</b> histogram plot of Actual Price column </center>

# %%
from sklearn.preprocessing import LabelEncoder
# label encode categorical variables

le_product_id = LabelEncoder()
le_category = LabelEncoder()
le_review_id = LabelEncoder()
le_review_content = LabelEncoder()
le_product_name = LabelEncoder()
le_user_name = LabelEncoder()
le_about_product = LabelEncoder()
le_user_id = LabelEncoder()
le_review_title = LabelEncoder()
le_img_link = LabelEncoder()
le_product_link = LabelEncoder()


df['product_id'] = le_product_id.fit_transform(df['product_id'])
df['category'] = le_category.fit_transform(df['category'])
df['review_id'] = le_review_id.fit_transform(df['review_id'])
df['review_content'] = le_review_content.fit_transform(df['review_content'])
df['product_name'] = le_product_name.fit_transform(df['product_name'])
df['user_name'] = le_user_name.fit_transform(df['user_name'])
df['about_product'] = le_about_product.fit_transform(df['about_product'])
df['user_id'] = le_user_id.fit_transform(df['user_id'])
df['review_title'] = le_review_title.fit_transform(df['review_title'])
df['img_link'] = le_img_link.fit_transform(df['img_link'])
df['product_link'] = le_product_link.fit_transform(df['product_link'])

# %%
# Plot correlations between variables
correlation_matrix = df.corr()
plt.figure(figsize=(18, 8))
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# <center> <b>Figure-5:</b> heatmap plot of Correlation </center>

# %%
# Calculate Pearson correlation coefficients (default in Pandas)
correlation_matrix = df.corr()

# Print the correlation matrix
print(correlation_matrix)

# Create a heatmap to visualize the correlations
plt.figure(figsize=(18, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix (Pearson)")
plt.show()

# Calculate Spearman correlation coefficients (for non-linear relationships)
spearman_correlation_matrix = df.corr(method="spearman")

# Print the Spearman correlation matrix
print(spearman_correlation_matrix)

# Create a heatmap to visualize the Spearman correlations
plt.figure(figsize=(18, 8))
sns.heatmap(spearman_correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix (Spearman)")
plt.show()
# Out:
#                      product_id  product_name  category  discounted_price  \
# product_id             1.000000      0.084089 -0.012565          0.206448
# product_name           0.084089      1.000000 -0.103778          0.090665
# category              -0.012565     -0.103778  1.000000          0.119365
# discounted_price       0.206448      0.090665  0.119365          1.000000
# actual_price           0.246733      0.078567  0.122451          0.961915
# discount_percentage    0.289514      0.101913 -0.314465         -0.242412
# rating                -0.149105     -0.035592 -0.109424          0.120386
# rating_count          -0.175530      0.092450 -0.098421         -0.027081
# about_product          0.041404      0.158263 -0.038753          0.052618
# user_id                0.065688     -0.024093  0.012707          0.041731
# user_name              0.016145      0.024598  0.037822         -0.063069
# review_id             -0.024282      0.013492  0.014015         -0.049757
# ...

# %% [markdown]
# <center> <b>Figure-6:</b> heatmap plot of Correlation </center>

# %%
# Calculate correlation coefficient between product price and sales
correlation_coefficient = np.corrcoef(df['actual_price'], df['rating'])[0, 1]

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# 0.12174449609998372

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   int32
#  1   product_name         1465 non-null   int32
#  2   category             1465 non-null   int32
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   int32
#  9   user_id              1465 non-null   int32
#  10  user_name            1465 non-null   int32
#  11  review_id            1465 non-null   int32
#  12  review_title         1465 non-null   int32
#  13  review_content       1465 non-null   int32
#  14  img_link             1465 non-null   int32
# ...

# %%
# inverse transform the data

df['product_id'] = le_product_id.inverse_transform(df['product_id'])
df['category'] = le_category.inverse_transform(df['category'])
df['review_id'] = le_review_id.inverse_transform(df['review_id'])
df['review_content'] = le_review_content.inverse_transform(df['review_content'])
df['product_name'] = le_product_name.inverse_transform(df['product_name'])
df['user_name'] = le_user_name.inverse_transform(df['user_name'])
df['about_product'] = le_about_product.inverse_transform(df['about_product'])
df['user_id'] = le_user_id.inverse_transform(df['user_id'])
df['review_title'] = le_review_title.inverse_transform(df['review_title'])
df['img_link'] = le_img_link.inverse_transform(df['img_link'])
df['product_link'] = le_product_link.inverse_transform(df['product_link'])

# %%
average_ratings = df.groupby("category")["rating"].mean().reset_index()
print(average_ratings)
# Out:
#                                               category    rating
# 0    Car&Motorbike|CarAccessories|InteriorAccessori...  3.800000
# 1    Computers&Accessories|Accessories&Peripherals|...  4.150000
# 2    Computers&Accessories|Accessories&Peripherals|...  3.500000
# 3    Computers&Accessories|Accessories&Peripherals|...  3.600000
# 4    Computers&Accessories|Accessories&Peripherals|...  4.050000
# 5    Computers&Accessories|Accessories&Peripherals|...  4.200000
# 6    Computers&Accessories|Accessories&Peripherals|...  4.033333
# 7    Computers&Accessories|Accessories&Peripherals|...  4.400000
# 8    Computers&Accessories|Accessories&Peripherals|...  4.400000
# 9    Computers&Accessories|Accessories&Peripherals|...  3.900000
# 10   Computers&Accessories|Accessories&Peripherals|...  4.151931
# 11   Computers&Accessories|Accessories&Peripherals|...  4.333333
# 12   Computers&Accessories|Accessories&Peripherals|...  4.100000
# ...

# %% [markdown]
# # <center> Take Insigns Use Groupby Function </center>

# %% [markdown]
# ## Q.1 Find the top 5 most expensive products in discounted price

# %%
product = df.groupby('product_name')['discounted_price'].mean().nlargest(5)
print(product.reset_index())
# Out:
#                                         product_name  discounted_price
# 0  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...           77990.0
# 1  OnePlus 163.8 cm (65 inches) U Series 4K LED S...           61999.0
# 2  VU 164 cm (65 inches) The GloLED Series 4K Sma...           54990.0
# 3  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...           47990.0
# 4  Samsung 138 cm (55 inches) Crystal 4K Neo Seri...           47990.0

# %% [markdown]
# ## Q.2 Find the top 5 most expensive products actual price

# %%
product = df.groupby('product_name')['actual_price'].mean().nlargest(5)
print(product.reset_index())
# Out:
#                                         product_name  actual_price
# 0  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...      139900.0
# 1  VU 164 cm (65 inches) The GloLED Series 4K Sma...       85000.0
# 2  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...       79990.0
# 3  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...       75990.0
# 4  Samsung Galaxy S20 FE 5G (Cloud Navy, 8GB RAM,...       74999.0

# %% [markdown]
# ## Q.3 Find the top 5 category based on rating counts

# %%
df.groupby('category')['rating'].value_counts().nlargest(5).reset_index()
# Out:
#                                             category  rating  count
# 0  Computers&Accessories|Accessories&Peripherals|...     4.3     45
# 1  Computers&Accessories|Accessories&Peripherals|...     4.2     43
# 2  Computers&Accessories|Accessories&Peripherals|...     4.0     40
# 3  Computers&Accessories|Accessories&Peripherals|...     4.1     35
# 4  Electronics|Mobiles&Accessories|Smartphones&Ba...     4.1     30

# %% [markdown]
# ## Q.4 What is the average rating for each product category?

# %%
df.groupby('category')['rating'].mean().reset_index().head()
# Out:
#                                             category  rating
# 0  Car&Motorbike|CarAccessories|InteriorAccessori...    3.80
# 1  Computers&Accessories|Accessories&Peripherals|...    4.15
# 2  Computers&Accessories|Accessories&Peripherals|...    3.50
# 3  Computers&Accessories|Accessories&Peripherals|...    3.60
# 4  Computers&Accessories|Accessories&Peripherals|...    4.05

# %% [markdown]
# ## Q.5 Find the top rating_count products by category?

# %%
df.groupby('category')['rating_count'].max().nlargest(5).reset_index()
# Out:
#                                             category  rating_count
# 0  Electronics|HomeTheater,TV&Video|Accessories|C...      426973.0
# 1  Electronics|Headphones,Earbuds&Accessories|Hea...      363713.0
# 2  Electronics|Mobiles&Accessories|Smartphones&Ba...      313836.0
# 3  Home&Kitchen|Kitchen&Dining|KitchenTools|Manua...      270563.0
# 4  Computers&Accessories|ExternalDevices&DataStor...      253105.0

# %% [markdown]
# ## Q.6 How does the average discount percentage vary across categories?

# %%
df.groupby('category')['discount_percentage'].mean().reset_index().head()
# Out:
#                                             category  discount_percentage
# 0  Car&Motorbike|CarAccessories|InteriorAccessori...                0.420
# 1  Computers&Accessories|Accessories&Peripherals|...                0.785
# 2  Computers&Accessories|Accessories&Peripherals|...                0.350
# 3  Computers&Accessories|Accessories&Peripherals|...                0.565
# 4  Computers&Accessories|Accessories&Peripherals|...                0.465

# %% [markdown]
# ## Q.7 Find the mean of top 5 products based on rating

# %%
df.groupby('product_name')['rating'].mean().nlargest(5).reset_index()
# Out:
#                                         product_name  rating
# 0  Amazon Basics Wireless Mouse | 2.4 GHz Connect...     5.0
# 1  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...     5.0
# 2  Syncwire LTG to USB Cable for Fast Charging Co...     5.0
# 3  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...     4.8
# 4  Oratech Coffee Frother electric, milk frother ...     4.8

# %% [markdown]
# ## Q.8 Find the top 5 category based on discounted price

# %%
df.groupby('category')['discounted_price'].value_counts().nlargest(5).reset_index()
# Out:
#                                             category  discounted_price  count
# 0  Computers&Accessories|Accessories&Peripherals|...             199.0     29
# 1  Computers&Accessories|Accessories&Peripherals|...             299.0     20
# 2  Computers&Accessories|Accessories&Peripherals|...             399.0     14
# 3        Electronics|WearableTechnology|SmartWatches            1999.0     12
# 4  Computers&Accessories|Accessories&Peripherals|...             349.0     11

# %% [markdown]
# ## Q.9 Find the top 5 category based on actual price

# %%
df.groupby('category')['actual_price'].value_counts().nlargest(10).reset_index()
# Out:
#                                             category  actual_price  count
# 0  Computers&Accessories|Accessories&Peripherals|...         999.0     40
# 1  Computers&Accessories|Accessories&Peripherals|...         399.0     21
# 2  Computers&Accessories|Accessories&Peripherals|...         499.0     18
# 3  Computers&Accessories|Accessories&Peripherals|...        1999.0     16
# 4  Computers&Accessories|Accessories&Peripherals|...        1099.0     15
# 5        Electronics|WearableTechnology|SmartWatches        9999.0     13
# 6  Computers&Accessories|Accessories&Peripherals|...         699.0     11
# 7        Electronics|WearableTechnology|SmartWatches        7990.0     11
# 8  Computers&Accessories|Accessories&Peripherals|...         599.0      9
# 9  Electronics|Headphones,Earbuds&Accessories|Hea...         999.0      9

# %% [markdown]
# ## Q.10 Find the top 5 products based on rating

# %%
df['product_name'].value_counts().sort_values(ascending=False).nlargest(5).reset_index()
# Out:
#                                         product_name  count
# 0  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...      5
# 1  Fire-Boltt Phoenix Smart Watch with Bluetooth ...      4
# 2  Ambrane 2 in 1 Type-C & Micro USB Cable with 6...      3
# 3  Pinnaclz Original Combo of 2 Micro USB Fast Ch...      3
# 4  Portronics Konnect L POR-1081 Fast Charging 3A...      3

# %% [markdown]
# ## Q.11 What are the most popular product keywords?

# %%
def extract_keywords(product_name):
  """Extracts keywords from a product name, handling potential numbers."""
  if isinstance(product_name, str):  # Check if it's a string
    keywords = product_name.lower().split()  # Split into words and lowercase
    keywords = [word for word in keywords if word.isalpha()]  # Remove non-alphabetical characters
  else:
    keywords = []  # Handle non-string values (e.g., integers) by returning an empty list
  return keywords

# Apply the function to extract keywords
df["keywords"] = df["product_name"].apply(extract_keywords)

# Flatten the list of keywords
all_keywords = [keyword for keywords in df["keywords"] for keyword in keywords]

# Count keyword occurrences
keyword_counts = pd.Series(all_keywords).value_counts()

# Display the top 10 most popular keywords
print(keyword_counts.head(10))
# Out:
# with        751
# for         672
# usb         377
# and         330
# cable       320
# charging    219
# to          218
# fast        211
# c           182
# smart       171
# Name: count, dtype: int64
